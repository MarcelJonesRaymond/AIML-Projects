# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcelJonesRaymond/AIML-Projects/blob/master/Computer_Vision_Week_1_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage.io as io
import matplotlib.pyplot as plt
import numpy as np

# %%
img = io.imread('/content/butterfly.jfif')
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (195, 258, 3)

# %%
red = img[:, :, 0]
green = img[:, :, 1]
blue = img[:, :, 2]

# %%
plt.imshow(green,cmap='Reds')
plt.show()

# %%
plt.imshow(red,cmap='Greens')

# %%
plt.imshow(blue,cmap='Blues')

# %%
def filtering(img, f=3):
    
    # Dimensions from the input shape
    (rows, col, channels) = img.shape
    
    # Initialize "hyper parameters"
    stride = 2
    
    # Dimensions of the output
    n_rows = int(1 + (rows - f) / stride)
    n_col = int(1 + (col - f) / stride)
    n_channels = channels
    
    # Initialize output matrix A
    n_img = np.zeros((n_rows, n_col, n_channels))              
    
    # iterate through img
    for h in range(n_rows):                     
        for w in range(n_col):                 
            for c in range (n_channels):            
                vert_start = h*stride
                vert_end = vert_start + f
                horiz_start = w*stride
                horiz_end = horiz_start + f

                # extract slice we are dealing with
                n_slice = img[vert_start:vert_end, horiz_start:horiz_end, c]

                # Compute the filtering operation on the slice
                n_img[h, w, c] = np.mean(n_slice, dtype=int)
    return n_img

# %%
A = filtering(img)
print(A.shape)
plt.imshow(A)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (97, 128, 3)

# %%
A =filtering(img,f=3)
plt.imshow(A)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
A = filtering(img, f=11)
plt.imshow(A)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
